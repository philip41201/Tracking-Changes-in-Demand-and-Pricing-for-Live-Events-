# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %%
api_url = 'https://app.ticketmaster.com/discovery/v2/events.json'
params = {'apikey':'API_KEY', 'keyword':'Garth Brooks', 'countryCode':'US'}
api_request = requests.get(api_url, params=params)

# %%
api_request
# Out:
# <Response [200]>

# %%
api_request.url
# Out:
# 'https://app.ticketmaster.com/discovery/v2/events.json?apikey=g41Q8ILou71Xrbkop2xuNXrS5pBo53hv&keyword=Garth+Brooks&countryCode=US'

# %%
json.loads(api_request.text)
# Out:
# {'_embedded': {'events': [{'name': 'Garth Brooks',
#     'type': 'event',
#     'id': 'vvG1YZ9kLFAxqp',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/garth-brooks-arlington-texas-07-30-2022/event/0C005C67C8162756',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
# ...

# %%
json.loads(api_request.text)['_embedded']['events']
# Out:
# [{'name': 'Garth Brooks',
#   'type': 'event',
#   'id': 'vvG1YZ9kLFAxqp',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/garth-brooks-arlington-texas-07-30-2022/event/0C005C67C8162756',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False},
#    {'ratio': '16_9',
# ...

# %%
details = json.loads(api_request.text)['_embedded']['events']

# %%
details[1]
# Out:
# {'name': 'Garth Brooks',
#  'type': 'event',
#  'id': 'G5viZpMBeSoTi',
#  'test': False,
#  'url': 'https://www.ticketmaster.com/garth-brooks-baton-rouge-louisiana-04-30-2022/event/1B005B7E82CD1FEC',
#  'locale': 'en-us',
#  'images': [{'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#    'width': 2048,
#    'height': 1152,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_ARTIST_PAGE_3_2.jpg',
#    'width': 305,
#    'height': 203,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_RETINA_PORTRAIT_16_9.jpg',
#    'width': 640,
#    'height': 360,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/78d/394b6b72-4a98-4742-afb2-bac783bca78d_438551_RETINA_LANDSCAPE_16_9.jpg',
# ...

# %%
event_details = {
    'event_id':[],
    'name':[],
    'venue':[],
    'city':[],
    'state':[],
    'publicOnSaleDate':[],
    'eventDate':[],
    'minPrice':[],
    'maxPrice':[],
    'url':[]
}

for event in details:
    event_id = event['id']
    event_details['event_id'].append(event_id)
    print(event_id)
    
    name = event['name']
    event_details['name'].append(name)
    print(name)
    
    venue = event['_embedded']['venues'][0]['name']
    event_details['venue'].append(venue)
    print(venue)
    
    city = event['_embedded']['venues'][0]['city']['name']
    event_details['city'].append(city)
    print(city)
    
    state = event['_embedded']['venues'][0]['state']['name']
    event_details['state'].append(state)
    print(state)
    
    publicOnSaleDate = event['sales']['public']['startDateTime'][0:10]
    event_details['publicOnSaleDate'].append(publicOnSaleDate)
    print(publicOnSaleDate)
    
    eventDate = event['dates']['start']['localDate']
    event_details['eventDate'].append(eventDate)
    print(eventDate)
    
    minPrice = event['priceRanges'][0]['min']
    event_details['minPrice'].append(minPrice)
    print(minPrice)
    
    maxPrice = event['priceRanges'][0]['max']
    event_details['maxPrice'].append(maxPrice)
    print(maxPrice)
    
    url = event['url']
    event_details['url'].append(url)
    print(url)
 
'''
event_details['event_id'].append(details[3]['id'])
event_details['name'].append(details[3]['name'])
event_details['venue'].append(details[3]['_embedded']['venues'][0]['name'])
event_details['city'].append(details[3]['_embedded']['venues'][0]['city']['name'])
event_details['state'].append(details[3]['_embedded']['venues'][0]['state']['name'])
event_details['publicOnSaleDate'].append(details[3]['sales']['public']['startDateTime'][0:10])
event_details['eventDate'].append(details[3]['dates']['start']['localDate'])
event_details['minPrice'].append(details[3]['priceRanges'][0]['min'])
event_details['maxPrice'].append(details[3]['priceRanges'][0]['max'])
event_details['url'].append(details[3]['url'])
'''
# Out:
# vvG1YZ9kLFAxqp
# Garth Brooks
# AT&T Stadium
# Arlington
# Texas
# 2022-04-15
# 2022-07-30
# 91.1
# 91.1
# https://www.ticketmaster.com/garth-brooks-arlington-texas-07-30-2022/event/0C005C67C8162756
# G5viZpMBeSoTi
# Garth Brooks
# LSU Tiger Stadium
# Baton Rouge
# Louisiana
# 2021-12-10
# 2022-04-30
# 87.7
# 87.7
# https://www.ticketmaster.com/garth-brooks-baton-rouge-louisiana-04-30-2022/event/1B005B7E82CD1FEC
# G5viZpMQ9Gejm
# Garth Brooks
# Donald W. Reynolds Razorback Stadium
# Fayetteville
# Arkansas
# 2021-12-03
# 2022-04-23
# 84.7
# 84.7
# https://www.ticketmaster.com/garth-brooks-fayetteville-arkansas-04-23-2022/event/1B005B769730272E
# vvG1fZ97UTZwF6
# Garth Brooks
# Notre Dame Stadium
# South Bend
# Indiana
# 2022-02-25
# 2022-05-07
# 91.7
# 91.7
# https://www.ticketmaster.com/garth-brooks-south-bend-indiana-05-07-2022/event/05005C4DBF032207
# vvG17Z9ewYmxCz
# Garth Brooks
# Gillette Stadium
# Foxborough
# Massachusetts
# 2021-02-14
# 2022-05-21
# 84.74
# 84.74
# ...

# %%
event_details
# Out:
# {'event_id': ['vvG1YZ9kLFAxqp',
#   'G5viZpMBeSoTi',
#   'G5viZpMQ9Gejm',
#   'vvG1fZ97UTZwF6',
#   'vvG17Z9ewYmxCz',
#   'G5vbZ9AS6qkCd',
#   'G5eZZ96tZ15UN',
#   'G5eVZ965LN9d7',
#   'G5eVZ9Ar8F3ZY',
#   'G5vzZ9Fh0m0RW',
#   'G5eFZ966AflHJ'],
#  'name': ['Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'Garth Brooks',
#   'KIX COUNTRY 98.7 FM Presents: Ultimate Garth - Garth Brooks Tribute'],
#  'venue': ['AT&T Stadium',
#   'LSU Tiger Stadium',
#   'Donald W. Reynolds Razorback Stadium',
#   'Notre Dame Stadium',
#   'Gillette Stadium',
#   'Paul Brown Stadium',
#   'Protective Stadium',
#   'Bank of America Stadium',
#   'Bank of America Stadium',
#   'Rice-Eccles Stadium',
#   'Oceanfront Bandshell'],
#  'city': ['Arlington',
#   'Baton Rouge',
#   'Fayetteville',
#   'South Bend',
#   'Foxborough',
#   'Cincinnati',
#   'Birmingham',
# ...

# %%
event_df = pd.DataFrame(event_details)

# %%
event_df.head()
# Out:
#          event_id          name                                 venue  \
# 0  vvG1YZ9kLFAxqp  Garth Brooks                          AT&T Stadium
# 1   G5viZpMBeSoTi  Garth Brooks                     LSU Tiger Stadium
# 2   G5viZpMQ9Gejm  Garth Brooks  Donald W. Reynolds Razorback Stadium
# 3  vvG1fZ97UTZwF6  Garth Brooks                    Notre Dame Stadium
# 4  vvG17Z9ewYmxCz  Garth Brooks                      Gillette Stadium
#
#            city          state publicOnSaleDate   eventDate  minPrice  \
# 0     Arlington          Texas       2022-04-15  2022-07-30     91.10
# 1   Baton Rouge      Louisiana       2021-12-10  2022-04-30     87.70
# 2  Fayetteville       Arkansas       2021-12-03  2022-04-23     84.70
# 3    South Bend        Indiana       2022-02-25  2022-05-07     91.70
# 4    Foxborough  Massachusetts       2021-02-14  2022-05-21     84.74
#
#    maxPrice                                                url
# ...

# %%
engine = create_engine('mysql+mysqldb://admin:sql_2022@tickets.ceaw7c57s0vu.us-east-1.rds.amazonaws.com/ticketmaster?charset=utf8')

# %%
event_df.to_sql('tm_event_details', engine, if_exists='append', index=False)

# %% [markdown]
# #
